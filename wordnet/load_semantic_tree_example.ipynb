# %%
import networkx as nx
from nltk.corpus import wordnet as wn
# need to install nltk and networkx
# also, you may need to download the wordnet data by running nltk.download('wordnet')

# %%
# load the semantic tree graph
graph = nx.read_gexf("semantic_tree.gexf")

# %%
# nodes are strings of synset names
print(list(graph.nodes()))

# this function converts a synset name to offsets (i.e. imagenet file id).
def to_offset_label(node):
    synset = wn.synset(node.split("'")[1])
    offset = synset.pos()+str(synset.offset()).zfill(8)
    return offset

print(to_offset_label(list(graph.nodes())[1]))
# Out:
# ["Synset('tench.n.01')", "Synset('goldfish.n.01')", "Synset('cyprinid.n.01')", "Synset('great_white_shark.n.01')", "Synset('fish.n.01')", "Synset('tiger_shark.n.01')", "Synset('shark.n.01')", "Synset('hammerhead.n.03')", "Synset('electric_ray.n.01')", "Synset('elasmobranch.n.01')", "Synset('stingray.n.01')", "Synset('ray.n.07')", "Synset('cock.n.05')", "Synset('vertebrate.n.01')", "Synset('hen.n.02')", "Synset('bird.n.01')", "Synset('ostrich.n.02')", "Synset('brambling.n.01')", "Synset('goldfinch.n.02')", "Synset('finch.n.01')", "Synset('house_finch.n.01')", "Synset('junco.n.01')", "Synset('indigo_bunting.n.01')", "Synset('robin.n.02')", "Synset('oscine.n.01')", "Synset('bulbul.n.01')", "Synset('thrush.n.03')", "Synset('jay.n.02')", "Synset('magpie.n.01')", "Synset('corvine_bird.n.01')", "Synset('chickadee.n.01')", "Synset('water_ouzel.n.01')", "Synset('kite.n.04')", "Synset('bald_eagle.n.01')", "Synset('bird_of_prey.n.01')", "Synset('vulture.n.01')", "Synset('great_grey_owl.n.01')", "Synset('european_fire_salamander.n.01')", "Synset('common_newt.n.01')", "Synset('salamander.n.01')", "Synset('eft.n.01')", "Synset('newt.n.01')", "Synset('spotted_salamander.n.01')", "Synset('axolotl.n.01')", "Synset('ambystomid.n.01')", "Synset('bullfrog.n.01')", "Synset('amphibian.n.03')", "Synset('tree_frog.n.02')", "Synset('frog.n.01')", "Synset('tailed_frog.n.01')", "Synset('loggerhead.n.02')", "Synset('leatherback_turtle.n.01')", "Synset('sea_turtle.n.01')", "Synset('mud_turtle.n.01')", "Synset('turtle.n.02')", "Synset('terrapin.n.01')", "Synset('box_turtle.n.01')", "Synset('banded_gecko.n.01')", "Synset('reptile.n.01')", "Synset('common_iguana.n.01')", "Synset('lizard.n.01')", "Synset('american_chameleon.n.01')", "Synset('iguanid.n.01')", "Synset('whiptail.n.01')", "Synset('agama.n.01')", "Synset('frilled_lizard.n.01')", "Synset('agamid.n.01')", "Synset('alligator_lizard.n.01')", "Synset('gila_monster.n.01')", "Synset('green_lizard.n.01')", "Synset('african_chameleon.n.01')", "Synset('komodo_dragon.n.01')", "Synset('african_crocodile.n.01')", "Synset('diapsid.n.01')", "Synset('american_alligator.n.01')", "Synset('crocodilian_reptile.n.01')", "Synset('triceratops.n.01')", "Synset('thunder_snake.n.01')", "Synset('ringneck_snake.n.01')", "Synset('colubrid_snake.n.01')", "Synset('hognose_snake.n.01')", "Synset('green_snake.n.02')", "Synset('king_snake.n.01')", "Synset('garter_snake.n.01')", "Synset('water_snake.n.01')", "Synset('vine_snake.n.01')", "Synset('night_snake.n.01')", "Synset('boa_constrictor.n.01')", "Synset('snake.n.01')", "Synset('rock_python.n.01')", "Synset('boa.n.02')", "Synset('indian_cobra.n.01')", "Synset('green_mamba.n.01')", "Synset('elapid.n.01')", "Synset('sea_snake.n.01')", "Synset('horned_viper.n.01')", "Synset('diamondback.n.01')", "Synset('viper.n.01')", "Synset('sidewinder.n.01')", "Synset('rattlesnake.n.01')", "Synset('trilobite.n.01')", "Synset('animal.n.01')", "Synset('harvestman.n.01')", "Synset('arthropod.n.01')", "Synset('scorpion.n.03')", "Synset('arachnid.n.01')", "Synset('black_and_gold_garden_spider.n.01')", "Synset('barn_spider.n.01')", "Synset('spider.n.01')", "Synset('garden_spider.n.01')", "Synset('black_widow.n.01')", "Synset('tarantula.n.02')", "Synset('wolf_spider.n.01')", "Synset('tick.n.02')", "Synset('centipede.n.01')", "Synset('black_grouse.n.01')", "Synset('ptarmigan.n.01')", "Synset('grouse.n.02')", "Synset('ruffed_grouse.n.01')", "Synset('prairie_chicken.n.01')", "Synset('peacock.n.02')", "Synset('game_bird.n.01')", "Synset('quail.n.02')", "Synset('phasianid.n.01')", "Synset('partridge.n.03')", "Synset('african_grey.n.01')", "Synset('macaw.n.01')", "Synset('parrot.n.01')", "Synset('sulphur-crested_cockatoo.n.01')", "Synset('lorikeet.n.01')", "Synset('coucal.n.01')", "Synset('bee_eater.n.01')", "Synset('hornbill.n.01')", "Synset('coraciiform_bird.n.01')", "Synset('hummingbird.n.01')", "Synset('jacamar.n.01')", "Synset('toucan.n.01')", "Synset('piciform_bird.n.01')", "Synset('drake.n.02')", "Sy ...
# n01443537

# %%
# edges are tuples: (in_node, out_node).
print(list(graph.edges()))
# Out:
# [("Synset('cyprinid.n.01')", "Synset('tench.n.01')"), ("Synset('cyprinid.n.01')", "Synset('goldfish.n.01')"), ("Synset('fish.n.01')", "Synset('elasmobranch.n.01')"), ("Synset('fish.n.01')", "Synset('food_fish.n.01')"), ("Synset('fish.n.01')", "Synset('teleost_fish.n.01')"), ("Synset('shark.n.01')", "Synset('great_white_shark.n.01')"), ("Synset('shark.n.01')", "Synset('tiger_shark.n.01')"), ("Synset('shark.n.01')", "Synset('hammerhead.n.03')"), ("Synset('elasmobranch.n.01')", "Synset('shark.n.01')"), ("Synset('elasmobranch.n.01')", "Synset('ray.n.07')"), ("Synset('ray.n.07')", "Synset('electric_ray.n.01')"), ("Synset('ray.n.07')", "Synset('stingray.n.01')"), ("Synset('vertebrate.n.01')", "Synset('fish.n.01')"), ("Synset('vertebrate.n.01')", "Synset('bird.n.01')"), ("Synset('vertebrate.n.01')", "Synset('amphibian.n.03')"), ("Synset('vertebrate.n.01')", "Synset('reptile.n.01')"), ("Synset('vertebrate.n.01')", "Synset('mammal.n.01')"), ("Synset('bird.n.01')", "Synset('cock.n.05')"), ("Synset('bird.n.01')", "Synset('hen.n.02')"), ("Synset('bird.n.01')", "Synset('ostrich.n.02')"), ("Synset('bird.n.01')", "Synset('oscine.n.01')"), ("Synset('bird.n.01')", "Synset('bird_of_prey.n.01')"), ("Synset('bird.n.01')", "Synset('game_bird.n.01')"), ("Synset('bird.n.01')", "Synset('parrot.n.01')"), ("Synset('bird.n.01')", "Synset('coucal.n.01')"), ("Synset('bird.n.01')", "Synset('coraciiform_bird.n.01')"), ("Synset('bird.n.01')", "Synset('hummingbird.n.01')"), ("Synset('bird.n.01')", "Synset('piciform_bird.n.01')"), ("Synset('bird.n.01')", "Synset('aquatic_bird.n.01')"), ("Synset('finch.n.01')", "Synset('brambling.n.01')"), ("Synset('finch.n.01')", "Synset('goldfinch.n.02')"), ("Synset('finch.n.01')", "Synset('house_finch.n.01')"), ("Synset('finch.n.01')", "Synset('junco.n.01')"), ("Synset('finch.n.01')", "Synset('indigo_bunting.n.01')"), ("Synset('oscine.n.01')", "Synset('finch.n.01')"), ("Synset('oscine.n.01')", "Synset('thrush.n.03')"), ("Synset('oscine.n.01')", "Synset('corvine_bird.n.01')"), ("Synset('oscine.n.01')", "Synset('chickadee.n.01')"), ("Synset('oscine.n.01')", "Synset('water_ouzel.n.01')"), ("Synset('thrush.n.03')", "Synset('robin.n.02')"), ("Synset('thrush.n.03')", "Synset('bulbul.n.01')"), ("Synset('corvine_bird.n.01')", "Synset('jay.n.02')"), ("Synset('corvine_bird.n.01')", "Synset('magpie.n.01')"), ("Synset('bird_of_prey.n.01')", "Synset('kite.n.04')"), ("Synset('bird_of_prey.n.01')", "Synset('bald_eagle.n.01')"), ("Synset('bird_of_prey.n.01')", "Synset('vulture.n.01')"), ("Synset('bird_of_prey.n.01')", "Synset('great_grey_owl.n.01')"), ("Synset('salamander.n.01')", "Synset('european_fire_salamander.n.01')"), ("Synset('salamander.n.01')", "Synset('newt.n.01')"), ("Synset('salamander.n.01')", "Synset('ambystomid.n.01')"), ("Synset('newt.n.01')", "Synset('common_newt.n.01')"), ("Synset('newt.n.01')", "Synset('eft.n.01')"), ("Synset('ambystomid.n.01')", "Synset('spotted_salamander.n.01')"), ("Synset('ambystomid.n.01')", "Synset('axolotl.n.01')"), ("Synset('amphibian.n.03')", "Synset('salamander.n.01')"), ("Synset('amphibian.n.03')", "Synset('frog.n.01')"), ("Synset('frog.n.01')", "Synset('bullfrog.n.01')"), ("Synset('frog.n.01')", "Synset('tree_frog.n.02')"), ("Synset('frog.n.01')", "Synset('tailed_frog.n.01')"), ("Synset('sea_turtle.n.01')", "Synset('loggerhead.n.02')"), ("Synset('sea_turtle.n.01')", "Synset('leatherback_turtle.n.01')"), ("Synset('turtle.n.02')", "Synset('sea_turtle.n.01')"), ("Synset('turtle.n.02')", "Synset('mud_turtle.n.01')"), ("Synset('turtle.n.02')", "Synset('terrapin.n.01')"), ("Synset('turtle.n.02')", "Synset('box_turtle.n.01')"), ("Synset('reptile.n.01')", "Synset('turtle.n.02')"), ("Synset('reptile.n.01')", "Synset('diapsid.n.01')"), ("Synset('lizard.n.01')", "Synset('banded_gecko.n.01')"), ("Synset('lizard.n.01')", "Synset('iguanid.n.01')"), ("Synset('lizard.n.01')", "Synset('whiptail.n.01')"), ("Synset('lizard.n.01')", "Synset('agamid.n.01')"), ("Synset('lizard.n.01')", "Synset('alligator_lizard.n.0 ...

# %%
# example of finding all children of a node "protective_covering"

# find the full name of the synset
node = [ n for n in graph.nodes() if "protective_covering" in n]
print(node)

# find all children of the node
children = list(graph.successors(node[0]))
print(children)

# convert the children to imagenet labels
children = [to_offset_label(c) for c in children]
print(children)
# Out:
# ["Synset('protective_covering.n.01')"]
# ["Synset('binder.n.03')", "Synset('shelter.n.02')", "Synset('lampshade.n.01')", "Synset('screen.n.05')", "Synset('armor_plate.n.01')", "Synset('sheath.n.01')", "Synset('armor.n.01')", "Synset('mask.n.04')", "Synset('roof.n.01')", "Synset('cap.n.04')", "Synset('blind.n.03')"]
# ['n02840245', 'n04191943', 'n03637318', 'n04151581', 'n02740764', 'n04187061', 'n02739668', 'n03725035', 'n04105068', 'n02955065', 'n02851099']

# %%
# number of nodes
print(len(graph.nodes()))
# Out:
# 1381

# %%
# number of leaves
print(len([n for n in graph.nodes() if len(list(graph.successors(n)))==0]))
# Out:
# 1000
